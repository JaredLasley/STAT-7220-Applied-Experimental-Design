# %%
# === COURSE REPO SETUP === #

# 1. ENTER your GitHub username (the one that owns your fork)
github_username = "JaredLasley"

# 2. Name of the repo (don't change unless your fork name is different)
repo_name = "STAT-7220-Applied-Experimental-Design"

# 3. Build the full repo URL for cloning
repo_url = f"https://github.com/{github_username}/{repo_name}.git"

import os

# --- Detect if we're already in a repo ---
cwd = os.getcwd()
if cwd.endswith(repo_name):
    print(f"✅ Already inside repo folder: {cwd}")
else:
    # --- If the repo folder exists, check if it's nested ---
    if os.path.exists(repo_name):
        print(f"⚠️ Found existing folder '{repo_name}'. Skipping clone to avoid nesting.")
    else:
        print(f"📥 Cloning repo from {repo_url}...")
        os.system(f"git clone {repo_url}")

    # --- Change to repo directory ---
    if os.path.exists(repo_name):
        os.chdir(repo_name)
        print(f"📂 Changed directory to: {os.getcwd()}")
    else:
        print("❌ ERROR: Repo folder not found. Please check your GitHub username.")

# --- Check if this is the instructor's repo instead of student's fork ---
# This command needs to be run from within the repository directory
remote_url = os.popen("git config --get remote.origin.url").read().strip()

if "abrown9008" in remote_url:
    print("⚠️ WARNING: You are working in the instructor's repo, not your fork!")
    print("💡 Please fork the repo to your own account and update `github_username` above.")
else:
    print(f"🔗 Connected to fork at: {remote_url}")

# Set Today's Directory #

today_dir = "Assignments/Final-Exam"
os.chdir(today_dir)
print(f"📂 Changed directory to: {os.getcwd()}")
# Out:
# 📥 Cloning repo from https://github.com/JaredLasley/STAT-7220-Applied-Experimental-Design.git...
# 📂 Changed directory to: /content/STAT-7220-Applied-Experimental-Design
# 🔗 Connected to fork at: https://github.com/JaredLasley/STAT-7220-Applied-Experimental-Design.git
# 📂 Changed directory to: /content/STAT-7220-Applied-Experimental-Design/Assignments/Final-Exam

# %% [markdown]
# # STAT 7220 - Final Exam
# ## Factorial Designs
# ## Dr. Austin Brown
# ## Due Date: May 11, 2026
#
# ## Part 1 Instructions:
# Let's say you own a new food truck called **Buster's Breakfast Burritos**. To determine the best ingredients for your burritos, and as a means of minimizing food (and money) waste, you decide to conduct an experiment. Specifically, you want to investigate the following treatments:
#
# | Factor   | Levels                  |
# |:---------|:------------------------|
# | Protein  | Bacon, Sausage, Chorizo |
# | Salsa    | Mild, Hot               |
# | Potatoes | Yes, No                 |
#
# To gather data for this experiment, you recruit $r=10$ local residents for each of the $3\times 2\times 2=12$ treatment combinations. After each participant has tasted their randomly assigned burrito, you ask them to rate the burrito on a scale of 1 to 10 (1 = terrible, 10 = amazing). The data are stored in the file `Busters Burritos.xlsx` in the assignment repo. With these data, I want you to:
#
# 1. Briefly state the objective of the experiment.
# * The primary objective of the experiment is to the best ingredients for breakfast buritos based on customer satisfaction scores.
#
# 2. State the outcome variable and how it was measured.
# * The outcome variable is Satisfaction(Continuous Numeric Variable)
#
# 3. State the independent variables. What lurking variables may be present?
# * **Independent Variables**
#   * Protein (nominal categorical variable)
#   * Salsa (nominal categorical variable)
#   * Potatoes (nominal categorical Variable)
# * **Lurking Variables**
#   * One possible lurking variable includes how hungry a participant is before eating the burrito. If a person is hungry they may unknowingly rate a buritto more favorably because it has sated their hunger.
#
# 4. Why might a full factorial design be preferred in this specific instance to a $2^k$ fractional factorial design?
# * A full factorial design would be prefferable in this instance to a $2^k$ because of the presence of a single category with 3 levels. If we were to choose a $2^k$ design we would lose fidelity in our protein factor for a rather marginal reduction in number of trials required.
#
# 5. State all sets of statistical hypotheses.
# * For our main effects:
# $$ H_{01}: \alpha_{\text{Bacon}} = \alpha_{\text{Sausage}} = \alpha_{\text{Chorizo}} = 0 $$
# $$ H_{11}: \text{At least one } \alpha_i \neq 0 $$
#
# $$ H_{02}: \beta_{\text{Mild}} = \beta_{\text{Hot}} = 0 $$
# $$ H_{12}: \text{At least one } \beta_j \neq 0 $$
#
# $$ H_{03}: \gamma_{\text{Potatoes}} = \gamma_{\text{No Potatoes}} = 0 $$
# $$ H_{13}: \text{At least one } \gamma_k \neq 0 $$
#
#
#
# * For our two-way interactions:
# $$ H_{04}: (\alpha\beta)_{ij} = 0 \text{ for all } i,j $$
# $$ H_{14}: \text{At least one } (\alpha\beta)_{ij} \neq 0 $$
#
# $$ H_{05}: (\alpha\gamma)_{ik} = 0 \text{ for all } i,k $$
# $$ H_{15}: \text{At least one } (\alpha\gamma)_{ik} \neq 0 $$
#
# $$ H_{06}: (\beta\gamma)_{jk} = 0 \text{ for all } j,k $$
# $$ H_{16}: \text{At least one } (\beta\gamma)_{jk} \neq 0 $$
#
#
# * For our three-way interaction:
# $$ H_{07}: (\alpha\beta\gamma)_{ijk} = 0 \text{ for all } i,j,k $$
# $$ H_{17}: \text{At least one } (\alpha\beta\gamma)_{ijk} \neq 0 $$
#
# 6. Perform appropriate exploratory/descriptive analysis including summary statistics and appropriate visualizations. Do these analyses provide any support for the hypotheses? Briefly explain.
# * **Interpreting the Main Effects:**
#
#     * **Protein:** While Chorizo did have the highest mean satisfaction score, all three protein options possess mean satisfaction scores within approximately one standard deviation.
#
#     * **Salsa:** Within each potato group, diners rated burritos with a mild salsa consistently more satisfactory than those with a hot salsa on average.
#
#     * **Potatoes:** Across the plots, the burritos with potatoes show a small mitigating effect on satisfaction scores. The mean satisfaction of the mild salsa group decreases while the hot salsa increases.
#
# * **Interpreting the Two-Way Interactions:**
#
#     * The slopes of the interaction lines within each potato group are not the same. This suggests a a possible significant two-way interaction effect between Protein and Salso.
#
# * **Interpreting the Three-Way Interaction:**
#
#     * Comparing the slopes of the interaction lines between the two potato groups, the change in slope do not appear significantly different. This visual similarity suggest a small to non-existent three-way interaction effect between Protein, Salso, and Potatoes. This is supported by the similarity of the satisfaction scores when all three treatments are considered. Overall these results more strongly support the null hypothesis

# %%
## Import Relevant Packages ##
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

## Read in burrito Data ##

burrito = pd.read_excel("Busters Burritos.xlsx")

## Data Integrity Check ##

print(burrito.info())

## Exploratory Data Analysis ##
## Start with Main Effects ##

## Protein ##

protien_stats = burrito.groupby("Protein")["Satisfaction"].agg(['mean', 'std'])

print(protien_stats)

## Salsa ##

Salsa_stats = burrito.groupby("Salsa")["Satisfaction"].agg(['mean', 'std'])

print(Salsa_stats)

## Potatoes ##

breath_stats = burrito.groupby("Potatoes")["Satisfaction"].agg(['mean', 'std'])

print(breath_stats)

#two-way interactions
## Protein x Salsa ##

sole_insole_stats = burrito.groupby(["Protein", "Salsa"])["Satisfaction"].agg(['mean', 'std'])

print(sole_insole_stats)

## Protein x Potatoes ##

sole_breath_stats = burrito.groupby(["Protein", "Potatoes"])["Satisfaction"].agg(['mean', 'std'])

print(sole_breath_stats)

## Salsa x Potatoes ##

insole_breath_stats = burrito.groupby(["Salsa", "Potatoes"])["Satisfaction"].agg(['mean', 'std'])

print(insole_breath_stats)

#three-way interactions
sole_insole_breath_stats = burrito.groupby(["Protein", "Salsa", "Potatoes"])["Satisfaction"].agg(['mean', 'std'])

print(sole_insole_breath_stats)

#plotting the data
## Install plotnine
#%pip install plotnine
## Import all plotnine functions ##:
from plotnine import *

# Prepare summarized data
burrito_means = sole_insole_breath_stats.reset_index()[["Protein", "Salsa", "Potatoes", "mean"]]

# Define dodge position for aligning points/lines with the boxplots
box_dodge = position_dodge(0.75)

# Build a single faceted plot
p = (
    ggplot(burrito, aes(x='Protein', y='Satisfaction')) +

    # 1. Boxplot layer (base visualization)
    geom_boxplot(aes(fill='Salsa'), alpha=0.7, position=box_dodge) +

    # 2. Mean points (using separate summary data)
    geom_point(
        data=burrito_means,
        mapping=aes(y='mean', group='Salsa'),
        shape='X',
        size=5,
        position=box_dodge,
        color='black'
    ) +

    # 3. Mean lines
    geom_line(
        data=burrito_means,
        mapping=aes(y='mean', group='Salsa', color='Salsa'),
        size=1.2,
        position=box_dodge
    ) +

    # 4. Facet by Potatoes (two panels side-by-side)
    facet_wrap('~Potatoes', ncol=2) +

    # 5. Styling and labels
    labs(
        title = "Satisfaction by Protein, Salsa, and Potatoes",
        x = "Protein",
        y = "Satisfaction",
        fill = "Salsa",
        color = "Salsa"
    ) +

    theme_classic() +
    theme(
        plot_title = element_text(hjust=0.5),
        strip_text = element_text(size=11, weight='bold')
    ) +

    scale_y_continuous(limits=(0, 15))
)

# Display
p
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Protein       120 non-null    object
#  1   Salsa         120 non-null    object
#  2   Potatoes      120 non-null    object
#  3   Satisfaction  120 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 3.9+ KB
# None
#            mean       std
# Protein
# Bacon    6.8500  0.928467
# Chorizo  7.0075  1.167374
# Sausage  5.7725  1.052710
#            mean       std
# Salsa
# Hot    6.070000  1.116031
# Mild   7.016667  1.055762
#               mean       std
# Potatoes
# No        6.335000  1.227071
# Yes       6.751667  1.105378
#                 mean       std
# Protein Salsa
# Bacon   Hot    6.450  0.870269
#         Mild   7.250  0.821744
# Chorizo Hot    6.470  1.090196
#         Mild   7.545  1.000250
# Sausage Hot    5.290  0.980279
# ...

# %% [markdown]
# 7. Fit the full factorial ANOVA model. Check the assumption of normality using a testing method and a visual method. Does the assumption hold? Why or why not?
# * On the QQ plot we can see that the majority of the data point lie on the 45 degree line bisecting the graph with minor devations of approximately 10 percent at the top and bottom ends of the line. This supports the assumption of normality. Additionaly, from the Shapiro-Wilk test we calculate a p-value=0.647 which fails to reject the null hypothesis at an alpha of 0.05. It follows that the statistical test also supports the assumption of normality.

# %%
## Import Statsmodels ##
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.diagnostic import het_breuschpagan
from scipy import stats

## Fit Full Factorial Model ##

model = ols('Satisfaction ~ Protein*Salsa*Potatoes', data=burrito).fit()

## Parse out model residuals ##

residuals = model.resid

## Test of Normality ##

## QQ-Plot ##

sm.qqplot(residuals, line='s')
plt.title("QQ-Plot of Model Residuals")
plt.show()

## Shapiro-Wilk Test ##

shapiro_test = stats.shapiro(residuals)

print("Shapiro-Wilk Test Results:")
print(f"Statistic: {shapiro_test.statistic}")
print(f"p-value: {shapiro_test.pvalue}")
if shapiro_test.pvalue < 0.05:
    print("Reject the null hypothesis - Residuals are not normally distributed.")
else:
    print("Fail to reject the null hypothesis - Residuals are normally distributed.")
# Out:
# Shapiro-Wilk Test Results:
# Statistic: 0.9912132000918904
# p-value: 0.6465112757958724
# Fail to reject the null hypothesis - Residuals are normally distributed.

# %% [markdown]
# 8. Check the assumption of constant variance using a testing method and a visual method. Does the assumption hold? Why or why not?
# * In the fitted vs. residual plot we can see a random scattering of data points with no clear patterns of coning or clustering. The data points are generally centered around a mean of zero. The banding in the data can be explained by the categorical nature of the variables. Additionally, the Breuch-Pagan test fails to reject the null hypothesis with a p-value=0.678, this further supports the assumption of homoscedasticity.

# %%
## Test of Homogeneity of Variance ##

## Scatterplot of Standardized Residuals vs. Fitted Values ##

## Get Standardized Residuals ##

standardized_residuals = model.get_influence().resid_studentized_internal

## Get Fitted Values ##

fitted_values = model.fittedvalues

## Scatterplot ##

## Create the plot ##

plt.figure(figsize=(8, 6))
sns.scatterplot(x=fitted_values, y=standardized_residuals)
plt.axhline(y=0, linestyle='dashed', color='red')
plt.axhline(y=3, color='blue')
plt.axhline(y=-3, color='blue')
plt.xlabel("Predicted y's")
plt.ylabel("Standardized Residuals")
plt.title("Standardized Residuals vs. Fitted Values")
plt.style.use('classic')
plt.show()

## B-P Test ##

## Run B-P Test ##

bp_test = het_breuschpagan(residuals, model.model.exog)

## Extract F-statistic ##

f_statistic = bp_test[2]

## Extract its P-Value ##

f_p_value = bp_test[3]

print(f"F-statistic: {f_statistic}")
print(f"F p-value: {f_p_value}")
if f_p_value < 0.05:
    print("Reject the null hypothesis - Variances are not equal.")
else:
    print("Fail to reject the null hypothesis - Variances are equal.")
# Out:
# F-statistic: 0.7602305270500087
# F p-value: 0.6784696565306803
# Fail to reject the null hypothesis - Variances are equal.

# %% [markdown]
# 9. Report the ANOVA table. What statistical conclusions can we draw about our main effects and interaction effects?
# * **Conclusions**
# - **Main Effects:**
#
#      - The main effect of Protein was statistically significant ($F=6.75$, $p=0.002$).
#
#      - The main effect of Salsa was statistically significant ($F=7.09$, $p=0.009$).
#
#      - The main effect of Potatoes was not statistically significant ($F=1.135$, $p=0.289$).
# - **Interaction Effects:**
#      - The three-way interaction term (Protein × Salsa × Potatoes) was not statistically significant ($F=0.486$, $p=0.617$).
#
#      - The two-way interaction terms (Protein × Salsa, Proteinl × Potatoes, Salsa × Potatoes) were also not statistically significant (all $p>0.05$).
#
#      - This aligns with the visual descriptive analysis and it simplifies the model, allows us to focus on the main effects.

# %%
## Print ANOVA Table Results ##

anova_table = sm.stats.anova_lm(model, typ=3)

## Add Significance Column ##

anova_table["Significance"] = np.where(anova_table["PR(>F)"] < 0.05, "Significant", "Not Significant")

## Print Table Minus Intercept and Residual Rows ##

print(anova_table.drop(index=["Intercept", "Residual"]))
# Out:
#                            sum_sq   df         F    PR(>F)     Significance
# Protein                 11.512667  2.0  6.750098  0.001729      Significant
# Salsa                    6.050000  1.0  7.094463  0.008916      Significant
# Potatoes                 0.968000  1.0  1.135114  0.289063  Not Significant
# Protein:Salsa            0.730333  2.0  0.428208  0.652777  Not Significant
# Protein:Potatoes         0.457333  2.0  0.268143  0.765306  Not Significant
# Salsa:Potatoes           0.900000  1.0  1.055375  0.306568  Not Significant
# Protein:Salsa:Potatoes   0.828167  2.0  0.485570  0.616683  Not Significant

# %% [markdown]
# 10. If the interactions and/or main effects were found to be statistically meaningful, conduct appropriate post-hoc tests. Report the results of these tests and any conclusions you can draw from them. If the interactions and/or main effects were not found to be statistically meaningful, explain why post-hoc tests would not be appropriate.
# * From the post-hoc testing conducted on Protein we can see that people do not have a clear prefrence between Bacon or Chorizo. However, there is a significant difference in the mean satisfaction ratings of people between both Bacon and Sausage as well as Chorizo and Sausage. Both pairings posses a p-value of 0. People are significantly less satisfied on average when consuming breakfast burritos with sausage comared to Chorizo or Bacon.

# %%
import statsmodels.stats.multicomp as mc

# Perform Tukey's HSD post-hoc test for Protein
mc_protein = mc.MultiComparison(burrito['Satisfaction'], burrito['Protein'])
protein_results = mc_protein.tukeyhsd()

print("Tukey's HSD Post-Hoc Test for Protein:")
print(protein_results)
# Out:
# Tukey's HSD Post-Hoc Test for Protein:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1  group2 meandiff p-adj   lower   upper  reject
# ------------------------------------------------------
#   Bacon Chorizo   0.1575 0.7824  -0.402   0.717  False
#   Bacon Sausage  -1.0775    0.0  -1.637  -0.518   True
# Chorizo Sausage   -1.235    0.0 -1.7945 -0.6755   True
# ------------------------------------------------------

# %% [markdown]
# 11. Calculate and interpret partial $\eta^2$ for the main effects.
# * Protein (np2 = 0.2819): This indicates that approximately 28.19% of the variance in Satisfaction is uniquely explained by Protein, making it a very large effect.
# * Salsa (np2 = 0.2260): Approximately 22.60% of the variance in Satisfaction is uniquely explained by Salsa, also indicating a very large effect.
# * Potatoes (np2 = 0.0535): Approximately 5.35% of the variance in Satisfaction is uniquely explained by Potatoes, which would be considered a small to medium effect.

# %%
## Load pingouin ##
#%pip install pingouin
import pingouin as pg

## Fit ANOVA with pingouin ##

mod_p = pg.anova(dv='Satisfaction',between=["Protein","Salsa","Potatoes"],data=burrito,effsize="np2").round(4)

print(mod_p[["Source","np2"]])
# Out:
#                        Source     np2
# 0                     Protein  0.2819
# 1                       Salsa  0.2260
# 2                    Potatoes  0.0535
# 3             Protein * Salsa  0.0041
# 4          Protein * Potatoes  0.0275
# 5            Salsa * Potatoes  0.0210
# 6  Protein * Salsa * Potatoes  0.0089
# 7                    Residual     NaN

# %% [markdown]
# 12. Give an overall conclusion for the experiment. Which burrito combination(s) should you include on your menu regularly? What are the limitations of your experiment? How could you improve it in the future?
# * In conclusion I would recommed that the menu should only include options for either Chorizo or Bacon for protein options as well as offering Hot and Mild Salsa. Sausage should be removed as it has a negative effect on customer satisfaction on average. Overall the presence or abscence of potatoes does not have a significant effect on the satisfaction rating of customers as such they should be removed from the menu to reduce complexity and increase efficency. Limitations of this experiment include a small number of trials for each unique combination. In the future this experiment could be improved by increasing the number of participants to test the effects on customer satisfaction of each breakfast burrito more broadly to ensure a more robust result.

# %% [markdown]
# ## Part 2 Instructions:
# After finalizing your breakfast burrito menu, now you want to focus Buster's Breakfast Burritos on maximizing sales through strategic placement of the truck itself and marketing. Obviously there are a lot of factors at play, so you decide to focus your attention on three: **Location** (could set up at a local brewery or at a local university); **Timing** (weekday or weekend); and **Marketing** (independently or in partnership with the brewery/university). See the below table:
#
# | Run | Location (A)    | Timing (B)   | Marketing (C)    |
# |-----|-----------------|--------------|------------------|
# | 1   | \- (Brewery)    | \- (Weekday) | \- (Independent) |
# | 2   | \+ (University) | \- (Weekday) | \+ (Partnership) |
# | 3   | \- (Brewery)    | \+ (Weekend) | \+ (Partnership) |
# | 4   | \+ (University) | \+ (Weekend) | \- (Independent) |
#
# To be more efficient with time and resources, you decide to conduct a $2^{3-1}$ fractional factorial design where your ultimate outcome is the sales amount (in dollars) for the day you set up. For each of the above runs, you will set up your truck $r=3$ times and record the sales amount. The data are stored in the `Busters Burrito Sales.xlsx` file in our course repo. With these day, I want you to:
#
# 1. Briefly describe the objective of the experiment.
# * The primary object of the experiment is to determine which combination of location, timing, and marketing factors results in the highest daily sales.
#
# 2. Specify the outcome variable and how it is measured.
# * The outcome variable is Sales(continuous numeric variable)
#
# 3. Specify the independent variables. What lurking variables may be present?
# * **Independent Variables**
#   * Location (nominal categorical variable)
#   * Timing (nominal categorical variable)
#   * Marketing (nominal categorical Variable)
# * **Lurking Variables**
#   * One possible lurking variable includes the number of events being hosted at either location on a given date. A special event hosted at the University or Brewery could cause the relationship between timing and location to change unexpectedly.
#
# 4. Explain why a fractional design is appropriate here. What are the advantages and disadvantages of using a fractional design?
# * Fractional design is appropriate here due to the state goal to be more efficient with time and resources. The primary advantage of fractional factorial design is that you will reqire fewer experimental runs to cover the test cases, however in exchange you lose the ability to distinghish between certain effects due to aliasing.
#
# 5. State the sets of null and alternative hypotheses for this experiment.
# * For our main effects:
# $$ H_{01}: \alpha_{\text{Brewery}} = \alpha_{\text{University}} = 0 $$
# $$ H_{11}: \text{At least one } \alpha_i \neq 0 $$
#
# $$ H_{02}: \beta_{\text{Weekday}} = \beta_{\text{Weekend}} = 0 $$
# $$ H_{12}: \text{At least one } \beta_j \neq 0 $$
#
# $$ H_{03}: \gamma_{\text{Independent}} = \gamma_{\text{Partnership}} = 0 $$
# $$ H_{13}: \text{At least one } \gamma_k \neq 0 $$
#
#
#
# * For our two-way interactions:
# $$ H_{04}: (\alpha\beta)_{ij} = 0 \text{ for all } i,j $$
# $$ H_{14}: \text{At least one } (\alpha\beta)_{ij} \neq 0 $$
#
# $$ H_{05}: (\alpha\gamma)_{ik} = 0 \text{ for all } i,k $$
# $$ H_{15}: \text{At least one } (\alpha\gamma)_{ik} \neq 0 $$
#
# $$ H_{06}: (\beta\gamma)_{jk} = 0 \text{ for all } j,k $$
# $$ H_{16}: \text{At least one } (\beta\gamma)_{jk} \neq 0 $$
#
#
# * For our three-way interaction:
# $$ H_{07}: (\alpha\beta\gamma)_{ijk} = 0 \text{ for all } i,j,k $$
# $$ H_{17}: \text{At least one } (\alpha\beta\gamma)_{ijk} \neq 0 $$
# 6. Perform appropriate exploratory/descriptive analysis including summary statistics and appropriate visualizations. Do these analyses provide any support for the hypotheses? Briefly explain.
# - From the information produced through the analyses and plots
#  * The University location has a lower mean sales figure than the Brewery (approximately $1\sigma$). The boxplot shows only slight overlap between the two location levels, which may indicate a meaningful effect.
#
# * For timing, we see that the weekend has a notably greater mean burrito sales (approximately $2\sigma$) than weekdays. The boxplots shows no overlap between the timing levels, which is suggestive of a significant effect.
#
# * Finally, we can see that marketing conducted in partnership with the university or brewery saw a greater mean sales figure than marketing conducted independently (approximately $1\sigma$). The boxplot demonstrates a significant overlap between marketing types, which is  suggestive of a neglegible effect.
#
# * Overall the results of these analyses more strongly support the alternative hypothesis.

# %%
## Import relevant libraries ##
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
## Read in the Data ##

sales = pd.read_excel("Busters Burrito Sales.xlsx")

## Location Effect ##

Location_effect = sales.groupby('Location')['Sales'].agg(['mean','std']).reset_index()

print(Location_effect)

## Timing Effect ##

Timing_effect = sales.groupby('Timing')['Sales'].agg(['mean','std']).reset_index()

print(Timing_effect)

## Marketing Effect ##

Marketing_effect = sales.groupby('Marketing')['Sales'].agg(['mean','std']).reset_index()

print(Marketing_effect)

## Plot Boxplots for Each Factor using seaborn ##

## Location Boxplot ##

sns.boxplot(x='Location', y='Sales', data=sales)
plt.title('Sales by Location')
plt.show()

## Timing Boxplot ##

sns.boxplot(x='Timing', y='Sales', data=sales)
plt.title('Sales by Timing')
plt.show()

## Marketing Boxplot ##
sns.boxplot(x='Marketing', y='Sales', data=sales)
plt.title('Sales by Marketing')
plt.show()
# Out:
#      Location         mean         std
# 0     Brewery  1130.844167  240.497137
# 1  University   969.116667  226.779048
#     Timing         mean         std
# 0  Weekday   856.971667  139.886119
# 1  Weekend  1242.989167  150.626558
#      Marketing         mean         std
# 0  Independent   956.325833  213.917393
# 1  Partnership  1143.635000  242.150011

# %% [markdown]
# 7. Assuming a defining relation of $I=ABC$, specify the aliasing structure of the design. What does this mean for the interpretation of the main effects and interactions?
# * Main Effect A:$$A \cdot I = A \cdot (ABC)$$$$A = A^2BC$$$$A = BC$$
# * Main Effect B:$$B \cdot I = B \cdot (ABC)$$$$B = AB^2C$$$$B = AC$$
# * Main Effect C:$$C \cdot I = C \cdot (ABC)$$$$C = ABC^2$$$$C = AB$$
#
# * In terms of interpretation of the main effects and interactions we are unable to determine the the effects of solely the main effects as when we calculate the effect of A we are actually calulating the effect of A +BC (Interaction Term) and so on for the other main effects and interactions.
#
# 8. Fit the appropriate ANOVA model to the data. Assess the normality assumption using two methods. Do we have evidence to support the assumption of normality? Why or why not?
# * While the QQ plot does show significant deviation at both ends of the 45 degree line, this is due to the small sample and categorcical nature of the data. The low number of categorical levels is the cause of the vertical line. In terms of statistical testing the calculated value from our Shapiro-Wilk is p = 0.936 which would lead us to fail to reject the null hypothesis, supporting the evidence for normality. Overall I believe the evidence supports the assumption of normality given the small sample size the the rest of the statistical testing.

# %%
## First, import ols function ##

from statsmodels.formula.api import ols
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.stats.diagnostic import het_breuschpagan

## Fit the Model

sales_mod = ols('Sales ~ Location + Timing + Marketing', data=sales).fit()
summary = sales_mod.summary()
print(summary)

## Test of Normality ##
## Extract Model Residuals ##

residuals = sales_mod.resid

## Use statsmodels to plot qqplot ##

sm.qqplot(residuals, line ='45')
plt.title('Q-Q Plot of Model Residuals')
plt.show()

## Run Shapiro-Wilk Test for Normality ##

shapiro_test = stats.shapiro(residuals)
print(f'Shapiro-Wilk Test Statistic: {shapiro_test.statistic}')
print(f'p-value: {shapiro_test.pvalue}')
if shapiro_test.pvalue < 0.05:
    print("Reject the null hypothesis: Residuals are not normally distributed.")
else:
    print("Fail to reject the null hypothesis: Residuals are normally distributed.")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.928
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                     86.36
# Date:                Mon, 11 May 2026   Prob (F-statistic):           1.28e-11
# Time:                        03:53:13   Log-Likelihood:                -133.75
# No. Observations:                  24   AIC:                             275.5
# Df Residuals:                      20   BIC:                             280.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                  844.1808     28.487     29.634      0.000     784.759     903.603
# ...

# %% [markdown]
# 9. Assess the constant variance assumption using two methods. Do we have evidence to support the assumption of constant variance? Why or why not?
# * In the fitted vs. residual plot we can see a random scattering of data points with no clear patterns of coning or clustering. The data points are generally centered around a mean of zero and within $3\sigma$ of the mean. The banding in the data can be explained by the categorical nature of the variables. Additionally, the Breuch-Pagan test fails to reject the null hypothesis with a p-value=0.818, this evidence supports the assumption of homoscedasticity.

# %%
## Generate Scatterplot of Standardized Residuals vs Fitted Values ##

standard_res = sales_mod.get_influence().resid_studentized_internal
fitted_vals = sales_mod.fittedvalues

sns.scatterplot(x=fitted_vals,y=standard_res)
plt.axhline(y=0, color='r', linestyle='--')
plt.axhline(y=3, color='b', linestyle='--')
plt.axhline(y=-3, color='b', linestyle='--')
plt.xlabel('Fitted Values')
plt.ylabel('Standardized Residuals')
plt.title('Standardized Residuals vs Fitted Values')
plt.show()

## Perform Breusch-Pagan Test for Homoscedasticity ##

bp_test = het_breuschpagan(residuals, sales_mod.model.exog)

## Extract F-statistic ##

f_statistic = bp_test[2]

## Extract its P-Value ##

f_p_value = bp_test[3]

print(f"F-statistic: {f_statistic}")
print(f"F p-value: {f_p_value}")
if f_p_value < 0.05:
    print("Reject the null hypothesis: Heteroscedasticity detected. Constant variance assumption violated.")
else:
    print("Fail to reject the null hypothesis: No heteroscedasticity detected. Constant variance assumption holds.")
# Out:
# F-statistic: 0.30964421419496124
# F p-value: 0.8181444641730525
# Fail to reject the null hypothesis: No heteroscedasticity detected. Constant variance assumption holds.

# %% [markdown]
# 10. Report and interpret the ANOVA table. What conclusions can we draw about our main effects? Do the results of these analyses support the null or alternative hypotheses more strongly?
#
# * Location:F(1) = 32.23, p<0.001
# * Timing: F(1) = 183.63, p<0.001
# * Marketing: F(1) = 43.23, p<0.001
#
# * Given an alpha of 0.05 all of the main effects are significant. The fact that all three main effects are signifcant more strongly supports the alternative hypothesis.

# %%
## Print the ANOVA table ##

print(sm.stats.anova_lm(sales_mod, typ=1))
# Out:
#              df         sum_sq        mean_sq           F        PR(>F)
# Location    1.0  156934.705537  156934.705537   32.231966  1.479823e-05
# Timing      1.0  894057.061837  894057.061837  183.625521  1.542764e-11
# Marketing   1.0  210508.343504  210508.343504   43.235165  2.091894e-06
# Residual   20.0   97378.301017    4868.915051         NaN           NaN

# %% [markdown]
# ### 11. Calculate and interpret the values for the main effects. Which effects seem more important? Why?
#
#
# * As **Location** goes from the Brewery (-) to the University (+), we expect a **decrease** of 16.39 dollars in average daily sales.
# * As **Timing** goes from Weekday (-) to Weekend (+), we expect an **increase** of 386.02 dollars in average daily sales.
# * As **Marketing** goes from Independent (-) to Partnership (+), we expect an **increase** of 187.31 dollars in average daily sales.
#
# **Timing** is clearly the most important factor, as its estimated effect (386.02) is significantly larger than the others, indicating that choosing the right day of the week has the largest impact on total sales.

# %%
import pandas as pd


effect_map = {1: '(1)', 2: 'ac', 3: 'bc', 4: 'ab'}


sales['Run_ID'] = np.repeat([1, 2, 3, 4], 6)
sales['Effect'] = sales['Run_ID'].map(effect_map)

## Group the Data by the Effect column and calculate means ##
df_means = sales.groupby("Effect")["Sales"].mean()


control = df_means['(1)']
ac = df_means['ac']
bc = df_means['bc']
ab = df_means['ab']

## Compute factor estimates ##
df_effects = pd.DataFrame({
    "A (Location)": [0.5 * (ab + ac - bc - control)],
    "B (Timing)": [0.5 * (ab + bc - ac - control)],
    "C (Marketing)": [0.5 * (ac + bc - ab - control)]
})

print("Average Sales per Effect:")
print(df_means, "\n")
print("Main Effect Estimates:")
print(df_effects)
# Out:
# Average Sales per Effect:
# Effect
# (1)     771.513333
# ab     1344.840000
# ac     1141.138333
# bc      942.430000
# Name: Sales, dtype: float64
#
# Main Effect Estimates:
#    A (Location)  B (Timing)  C (Marketing)
# 0      386.0175  187.309167       -16.3925

# %% [markdown]
# 12. Calculate and interpret the partial $\eta^2$ for the main effects. Which effects seem more important? Why?
#
# * **Timing** and **Marketing** are the two most important main effects, accounting for approximately **92.47%** and **74.29%** of the variance respectively.
# * **Location** is also important but to a slightly lesser degree than the other two, accounting for approximately **68.30%** of the variance.

# %%
## Calculate Partial Eta Squared for Each Factor ##

## Load pingouin ##

import pingouin as pg

## Fit ANOVA with pingouin ##

mod2 = pg.anova(data=sales, dv='Sales', between=['Location','Timing','Marketing'], detailed=True)

print(mod2[["Source","np2"]][:3])
# Out:
#       Source       np2
# 0   Location  0.682968
# 1     Timing  0.924658
# 2  Marketing  0.742908

# %% [markdown]
# 13. Give an overall conclusion for the experiment. Which location, timing, and marketing combination(s) should you use to maximize sales? What are the limitations of your experiment? How could you improve it in the future?
#
# ## Part 3 Instructions:
#
# Please briefly repond to the following questions:
#
# 1. How do we de-alias the main effects and interactions in a fractional factorial design? Why is this important? Why may it not always be feasible?
#
# * We de-alias effects by first determining the aliasing structure via the design's defining relation, then conducting strategic follow up experiments such as a fold over design to break those specific confounding chains. This process is vital because it isolates the true impact of main effects and lower-order interactions, ensuring we don't attribute statistical significance to the wrong variables. However, executing these additional experimental runs is not always feasible in practice due to strict limitations on budget, time, or material resources.
#
# 2. In all of our assignments, I have had you specify/consider a lot of characteristics of an experiment before getting into the analysis. Why is this good practice?
# * It is good practice to consider the characteristics of an experiment before conducting an analysis because the characteristics of the experiment affect which analyses are applicable to answer the question(s) being asked. There are many examples of this such as selecting the type of model used for analysis, use of higher-order terms, or simple variable selection.
#
# 3. What is the difference between a fixed effect and a random effect?
# * The primary difference between a random effect and a fixed effect is how we treat the levels of categorical variables under analysis. In fixed effect we are concerned with comparing the means of the response variable across every level the categorical in question. While in contrast when exploring a random effect we are intrested in comparing only the variance of the levels as a whole.
#
# 4. What is the most important thing you learned in this class?
# * There are many ways to skin a cat. Coming into this course I was only familiar with completely randomized designs for experiments. My repotoire of scientific tools has greatly expanded. I now understand that when designing experiments there are many factors which influence how the experiment will be conducted as well as many options for how to conduct an experiment to answer a research question.
